# %% [markdown]
# <a href="https://colab.research.google.com/github/Azinshahiri/Python/blob/main/newton_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
x = sp.Symbol('x')
f = x**3 -2*x -5
f_prime=f.diff(x)
f=lambdify(x,f)
f_prime =lambdify(x,f_prime)

# %%
x=float(input("Please enter the value of the x (approximate value):"))
n=int(input("Please enter the correct Decimal place:"))
i=1

condition= True
while condition:
  f_2= str(x)
  x_n = x -(f(x)/f_prime(x))
  print("i = ",i , " x = ", x_n, "f(x) =" , f(x))
  a=str(x_n)

  if a[0:n+2] == f_2[0:n+2]:
    condition=False
  else:
    condition=True
    x = x_n
    i =i+1
x=str(x)
s=x[0:n+2]
print("requierd value is:", s)

m=np.linspace(-3,3,100)
y=f(m)
plt.plot(m,y)
plt.grid()
s=float(s)
plt.plot(s,0, marker="o",color= "red")
# Out:
# Please enter the value of the x (approximate value):0
# Please enter the correct Decimal place:3
# i =  1  x =  -2.5 f(x) = -5.0
# i =  2  x =  -1.5671641791044775 f(x) = -15.625
# i =  3  x =  -0.5025924450866799 f(x) = -5.714632451465106
# i =  4  x =  -3.820706467699331 f(x) = -4.1217695422221725
# i =  5  x =  -2.5493933913606077 f(x) = -53.132487962368245
# i =  6  x =  -1.6081114997282262 f(x) = -16.470757614024038
# i =  7  x =  -0.5761004336602411 f(x) = -5.942389675017669
# i =  8  x =  -4.597709583382194 f(x) = -4.039002090544909
# i =  9  x =  -3.083543146726672 f(x) = -92.99525756923606
# i =  10  x =  -2.022194255464349 f(x) = -28.15197687028246
# i =  11  x =  -1.1237641075795322 f(x) = -9.224908997053978
# i =  12  x =  1.2086516123956688 f(x) = -4.171612533995735
# i =  13  x =  3.580790044897399 f(x) = -5.651658150236064
# i =  14  x =  2.655233198009221 f(x) = 33.7515152085633
# i =  15  x =  2.216106307438693 f(x) = 8.409626867932232
# ...
